# %%
import numpy as np
import pandas as pd

# %%
myindex = ["USA", 'Canada','Mexico']
mydata = [1776, 1867,1821]

# %%
myser = pd.Series(data=mydata, index = myindex)

# %%
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
ages = {'Sam':4, 'Frank' :10, 'Mako' :2}

# %%
pd.Series(ages)
# Out:
# Sam       4
# Frank    10
# Mako      2
# dtype: int64

# %%
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1 = pd.Series(q1)

# %%
print(sales_q1)
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2 = pd.Series(q2)

# %%
print(sales_q2)
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q2["Brazil"]
# Out:
# 100

# %%
sales_q2.keys()
# Out:
# Index(['Brazil', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q2 + sales_q1
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2, fill_value = 0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
sales_q2.dtype
# Out:
# dtype('int64')

# %%
sales_q2 =pd.Series.dtype = 'Str'

# %%
print(type(sales_q2))
# Out:
# <class 'str'>

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA','NY','AZ','TX']

# %%
mycolumns = ['Jan','Feb','Mar']

# %%
df = pd.DataFrame(mydata, myindex, mycolumns)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
pwd
# Out:
# 'C:\\Users\\Makhmudkozha\\JupitorRoot\\NewStart'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7A23-E798
#
#  Directory of C:\Users\Makhmudkozha\JupitorRoot\NewStart
#
# 10/30/2024  01:51 AM    <DIR>          .
# 10/30/2024  01:51 AM    <DIR>          ..
# 10/29/2024  08:23 PM    <DIR>          .ipynb_checkpoints
# 10/25/2024  01:25 AM            12,882 Circles.ipynb
# 10/24/2024  03:52 AM            15,137 Collections.ipynb
# 10/25/2024  09:36 PM             7,030 Decorators.ipynb
# 07/04/2020  07:39 PM                51 example.csv
# 10/23/2024  01:44 AM                28 example.txt
# 09/26/2020  02:14 PM             5,022 example.xlsx
# 10/25/2024  09:16 PM             9,796 Functions.ipynb
# 07/12/2020  02:41 PM        25,112,317 hotel_booking_data.csv
# 02/07/2020  02:26 PM               177 movie_scores.csv
# 07/01/2020  05:56 PM            17,727 mpg.csv
# 07/04/2020  07:58 PM             5,022 my_excel_file.xlsx
# 07/04/2020  08:10 PM                51 new_file.csv
# ...

# %%
df = pd.read_csv('C:\\Users\\Makhmudkozha\\JupitorRoot\\NewStart\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 234    Tracy Douglas  4097938155941930    Sat7220
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
mycols = ['total_bill', 'tip']
df[mycols]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['tip'] + df['total_bill']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244

# %%
df['tip_percentage'] = np.round(100 * df['tip'] / df['total_bill'],2)

# %%
df['tip_percentage']
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 239    20.39
# 240     7.36
# 241     8.82
# 242     9.82
# 243    15.97
# Name: tip_percentage, Length: 244

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
df =df.drop('tip_percentage', axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.set_index('Payment ID')

# %%
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959', 'Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.drop('Sun5260', axis = 0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.iloc[1:]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959

# %%
df.append(one_row)
# Out:
# C:\Users\Makhmudkozha\AppData\Local\Temp\ipykernel_28904\1271293785.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(one_row)
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# ...

# %%
df = pd.concat([df,pd.DataFrame([one_row])], axis =0)

# %%
df
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number
# Sun2959              8.49  Christy Cunningham  3560325168603410
# Sun4608              3.45      Douglas Tucker  4478071379779230
# ...

# %%
df
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number
# Sun2959              8.49  Christy Cunningham  3560325168603410
# Sun4608              3.45      Douglas Tucker  4478071379779230
# ...

# %%
df['total_bill'] > 40
# Out:
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 245

# %%
more_than_40 = df['total_bill'] > 40

# %%
more_than_40
# Out:
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 245

# %%
more_than_40 = df['total_bill'] > 40

# %%
print(more_than_40)
# Out:
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 245

# %%
print(df.dtypes)
# Out:
# total_bill          float64
# tip                 float64
# sex                  object
# smoker               object
# day                  object
# time                 object
# size                  int64
# price_per_person    float64
# Payer Name           object
# CC Number             int64

# %%
if 'total_bill' in df.columns:
    more_than_40 = df['total_bill'] > 40
    print("Boolean mask for total_bill > 40:")
    print(more_than_40)  # Display the boolean mask
# Out:
# Boolean mask for total_bill > 40:
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Sun2959    False
# Name: total_bill, Length: 245
